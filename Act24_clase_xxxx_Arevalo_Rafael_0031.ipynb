# %% [markdown]
# <a href="https://colab.research.google.com/github/ArevaloMurguia/-Act24-clase-xxxx-Arevalo-Rafael-0031/blob/main/Act24_clase_xxxx_Arevalo_Rafael_0031.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Arevalo Rafael ♏ NL = 3 Fecha:27/Abr/26
# ### Clase Libros
# <img src="https://raw.githubusercontent.com/ArevaloMurguia/-Act24-clase-xxxx-Arevalo-Rafael-0031/refs/heads/main/InfoLibro.png" width="900" height="600" alt="Texto descriptivo">

# %%
class Libro:
    def __init__(self, titulo, autor, genero, numeroPaginas):
        self.titulo = titulo
        self.autor = autor
        self.genero = genero
        self.numeroPaginas = numeroPaginas
        self.paginaActual = 0 # Asumiendo una página inicial por defecto

    def abrir(self):
        print(f"Abriendo el libro: {self.titulo}")

    def marcarPagina(self, pagina):
        if 0 < pagina <= self.numeroPaginas:
            self.paginaActual = pagina
            print(f"Página {pagina} marcada.")
        else:
            print(f"La página {pagina} está fuera del rango del libro (1-{self.numeroPaginas}).")

    def buscarCapitulo(self, capitulo):
        print(f"Buscando el capítulo '{capitulo}' en {self.titulo}...")
        # Lógica de búsqueda de capítulo podría ir aquí
        print("Búsqueda simulada. El capítulo se encontraría si existiera la lógica de búsqueda.")

# Programa interactivo

titulo = input("Ingresa el título del libro: ")
autor = input("Ingresa el autor: ")
genero = input("Ingresa el género: ")
paginas = int(input("Ingresa el número de páginas: "))

mi_libro = Libro(titulo, autor, genero, paginas)

print("\nDatos del libro:")
print(f"Título: {mi_libro.titulo}")
print(f"Autor: {mi_libro.autor}")
print(f"Género: {mi_libro.genero}")
print(f"Páginas: {mi_libro.numeroPaginas}")

mi_libro.abrir()

pagina = int(input("\n¿Qué página deseas marcar? "))
mi_libro.marcarPagina(pagina)

capitulo = input("¿Qué capítulo deseas buscar? ")
mi_libro.buscarCapitulo(capitulo)

print("Programa generado por Arevalo Rafael 0031")
# Out:
# Ingresa el título del libro: El quijote
# Ingresa el autor: Cervantes
# Ingresa el género: Novela
# Ingresa el número de páginas: 1200
#
# Datos del libro:
# Título: El quijote
# Autor: Cervantes
# Género: Novela
# Páginas: 1200
# Abriendo el libro: El quijote
#
# ¿Qué página deseas marcar? 800
# Página 800 marcada.
# ¿Qué capítulo deseas buscar? 8
# Buscando el capítulo '8' en El quijote...
# Búsqueda simulada. El capítulo se encontraría si existiera la lógica de búsqueda.
# Programa generado por Arevalo Rafael 0031

# %% [markdown]
# <img src="https://raw.githubusercontent.com/ArevaloMurguia/-Act24-clase-xxxx-Arevalo-Rafael-0031/refs/heads/main/TldrawLibro.png" width="1000" height="600" alt="Texto descriptivo">
